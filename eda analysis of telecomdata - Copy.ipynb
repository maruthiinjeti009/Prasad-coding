# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
telecom=pd.read_csv("telecom_curn.csv")

# %%
telecom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
telecom.shape
# Out:
# (7043, 21)

# %%
list(telecom.columns)
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
telecom.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
telecom.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
telecom.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telecom["TotalCharges"].value_counts()
# Out:
#            11
# 20.2       11
# 19.75       9
# 19.9        8
# 20.05       8
# 19.65       8
# 45.3        7
# 19.55       7
# 20.25       6
# 20.15       6
# 19.45       6
# 20.45       5
# 20.3        5
# 19.5        4
# 69.6        4
# 19.85       4
# 19.4        4
# 44          4
# 20.35       4
# 49.9        4
# 70.6        4
# 69.95       4
# 69.65       4
# 19.95       4
# 20.4        4
# 19.3        4
# 74.7        4
# 44.4        4
# 20.5        4
# 19.2        4
#            ..
# 318.9       1
# 1573.95     1
# 345.9       1
# 4807.45     1
# 2730.85     1
# 1240.25     1
# 34.75       1
# 1430.25     1
# 1397.65     1
# 1660        1
# 3233.85     1
# 8310.55     1
# 2633.3      1
# 1181.75     1
# 2483.05     1
# 1931.3      1
# 6536.5      1
# 75.5        1
# 7069.3      1
# 1013.2      1
# 1426.45     1
# 1801.9      1
# 458.1       1
# 798.2       1
# 3488.15     1
# 100.2       1
# 6823.4      1
# 7040.85     1
# 521.1       1
# 678.2       1
# ...

# %%
telecom.shape
# Out:
# (7043, 21)

# %%
telecom["TotalCharges"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f6ffdb82b299> in <module>()
# ----> 1 telecom["TotalCharges"].astype(float)
#
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
# ...

# %%
telecom.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
telecom.fillna(method="bfill")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
sns.boxplot(telecom["SeniorCitizen"])

# %%
telecom["SeniorCitizen"].describe()
# Out:
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64

# %%
sns.boxplot(telecom["tenure"])

# %%
sns.boxplot(telecom["MonthlyCharges"])

# %% [markdown]
# ##bivariate analysis

# %%
telecom.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["gender"])
# Out:
# gender         Female  Male
# SeniorCitizen
# 0                2920  2981
# 1                 568   574

# %%
telecom["tenure"].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
def abc(tenure):
    if tenure>=0 and tenure<=9:
        return "0-9"
    elif tenure>9 and tenure<=29:
        return "9-29"
    elif tenure>29 and tenure<=55:
        return "29-55"
    else:
        return "55-72"

# %%
telecom["tenure_bin"]=telecom["tenure"].apply(abc)

# %%
tenure_freq=telecom["tenure_bin"].value_counts()/len(telecom)*100

# %%
plt.bar(tenure_freq.index,tenure_freq.values)
# Out:
# <BarContainer object of 4 artists>

# %%
telecom["MonthlyCharges"].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
def abc(MonthlyCharges):
    if MonthlyCharges>=18 and MonthlyCharges<=35:
        return "18-35"
    elif MonthlyCharges>35 and MonthlyCharges<=70:
        return "35-70"
    elif MonthlyCharges>70 and MonthlyCharges<=89:
        return "70-89"
    else:
        return "118"

# %%
telecom["MonthlyCharges_bin"]=telecom["MonthlyCharges"].apply(abc)

# %%
MonthlyCharges_freq=telecom["MonthlyCharges_bin"].value_counts()/len(telecom)*100

# %%
plt.bar(MonthlyCharges_freq.index,MonthlyCharges_freq.values)
# Out:
# <BarContainer object of 4 artists>

# %%
telecom["TotalCharges"].describe()
# Out:
# count     7043
# unique    6531
# top
# freq        11
# Name: TotalCharges, dtype: object

# %%
def abc(TotalCharges):
    if TotalCharges>=18 and TotalCharges<=401:
        return "18-401"
    elif TotalCharges>401 and TotalCharges<=1397:
        return "401-1397"
    elif TotalCharges>1397 and TotalCharges<=3794:
        return "1397-3794"
    else:
        return "8684"

# %%
telecom["TotalCharges_bin"]=telecom["TotalCharges"].apply(abc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ab63adbf0d88> in <module>()
# ----> 1 telecom["TotalCharges_bin"]=telecom["TotalCharges"].apply(abc)
#
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-30-3fd2d475a3ef> in abc(TotalCharges)
#       1 def abc(TotalCharges):
# ----> 2     if TotalCharges>=18 and TotalCharges<=401:
#       3         return "18-401"
#       4     elif TotalCharges>401 and TotalCharges<=1397:
# ...

# %%
TotalCharges_freq=telecom["TotalCharges_bin"].value_counts()/len(telecom)*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalCharges_bin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.bar(TotalCharges_freq.index,TotalCharges_freq.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c7884f6ff35f> in <module>()
# ----> 1 plt.bar(TotalCharges_freq.index,TotalCharges_freq.values)
#
# NameError: name 'TotalCharges_freq' is not defined

# %%
pd.crosstab(telecom["tenure_bin"],telecom["gender"])
# Out:
# gender      Female  Male
# tenure_bin
# 0-9            918   936
# 29-55          863   856
# 55-72          856   899
# 9-29           851   864

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["gender"])
# Out:
# gender              Female  Male
# MonthlyCharges_bin
# 118                    934   956
# 18-35                  849   886
# 35-70                  839   886
# 70-89                  866   827

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["gender"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalCharges_bin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["Partner"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalCharges_bin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["Partner"])
# Out:
# Partner               No   Yes
# MonthlyCharges_bin
# 118                  796  1094
# 18-35                925   810
# 35-70               1001   724
# 70-89                919   774

# %%
pd.crosstab(telecom["tenure_bin"],telecom["Partner"])
# Out:
# Partner       No   Yes
# tenure_bin
# 0-9         1402   452
# 29-55        780   939
# 55-72        451  1304
# 9-29        1008   707

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["Partner"])
# Out:
# Partner          No   Yes
# SeniorCitizen
# 0              3072  2829
# 1               569   573

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["Dependents"])
# Out:
# Dependents            No  Yes
# MonthlyCharges_bin
# 118                 1407  483
# 18-35               1039  696
# 35-70               1209  516
# 70-89               1278  415

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["Dependents"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalCharges_bin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(telecom["tenure_bin"],telecom["Dependents"])
# Out:
# Dependents    No  Yes
# tenure_bin
# 0-9         1494  360
# 29-55       1147  572
# 55-72       1069  686
# 9-29        1223  492

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["Dependents"])
# Out:
# Dependents       No   Yes
# SeniorCitizen
# 0              3882  2019
# 1              1051    91

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["PhoneService"])
# Out:
# PhoneService    No   Yes
# SeniorCitizen
# 0              578  5323
# 1              104  1038

# %%
pd.crosstab(telecom["tenure_bin"],telecom["PhoneService"])
# Out:
# PhoneService   No   Yes
# tenure_bin
# 0-9           185  1669
# 29-55         175  1544
# 55-72         156  1599
# 9-29          166  1549

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["PhoneService"])
# Out:
# PhoneService         No   Yes
# MonthlyCharges_bin
# 118                   0  1890
# 18-35               209  1526
# 35-70               473  1252
# 70-89                 0  1693

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["PhoneService"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalCharges_bin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["MultipleLines"])
# Out:
# MultipleLines    No  No phone service   Yes
# SeniorCitizen
# 0              3017               578  2306
# 1               373               104   665

# %%
pd.crosstab(telecom["tenure_bin"],telecom["MultipleLines"])
# Out:
# MultipleLines    No  No phone service   Yes
# tenure_bin
# 0-9            1279               185   390
# 29-55           721               175   823
# 55-72           459               156  1140
# 9-29            931               166   618

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["MultipleLines"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\praveen hp\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalCharges_bin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["MultipleLines"])
# Out:
# MultipleLines         No  No phone service   Yes
# MonthlyCharges_bin
# 118                  447                 0  1443
# 18-35               1184               209   342
# 35-70                947               473   305
# 70-89                812                 0   881

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["InternetService"])
# Out:
# InternetService   DSL  Fiber optic    No
# SeniorCitizen
# 0                2162         2265  1474
# 1                 259          831    52

# %%
pd.crosstab(telecom["tenure_bin"],telecom["InternetService"])
# Out:
# InternetService  DSL  Fiber optic   No
# tenure_bin
# 0-9              638          788  428
# 29-55            584          780  355
# 55-72            623          790  342
# 9-29             576          738  401

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["InternetService"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["InternetService"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["OnlineSecurity"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["OnlineSecurity"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["OnlineSecurity"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["OnlineSecurity"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["OnlineBackup"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["OnlineBackup"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["OnlineBackup"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["OnlineBackup"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["DeviceProtection"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["DeviceProtection"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["DeviceProtection"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["DeviceProtection"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["TechSupport"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["TechSupport"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["TechSupport"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["TechSupport"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["StreamingTV"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["StreamingTV"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["StreamingTV"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["StreamingTV"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["Contract"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["Contract"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["Contract"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["Contract"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["StreamingMovies"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["StreamingMovies"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["StreamingMovies"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["StreamingMovies"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["PaperlessBilling"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["PaperlessBilling"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["PaperlessBilling"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["PaperlessBilling"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["PaymentMethod"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["PaymentMethod"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["PaymentMethod"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["PaymentMethod"])

# %%
pd.crosstab(telecom["SeniorCitizen"],telecom["Churn"])

# %%
pd.crosstab(telecom["tenure_bin"],telecom["Churn"])

# %%
pd.crosstab(telecom["MonthlyCharges_bin"],telecom["Churn"])

# %%
pd.crosstab(telecom["TotalCharges_bin"],telecom["Churn"])
